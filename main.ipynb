# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# datset: https://www.kaggle.com/datasets/fratzcan/usa-house-prices

data = pd.read_csv("dataset.csv")
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-09 00:00:00   376000.0       3.0       2.00         1340      1384
# 1  2014-05-09 00:00:00   800000.0       4.0       3.25         3540    159430
# 2  2014-05-09 00:00:00  2238888.0       5.0       6.50         7270    130017
# 3  2014-05-09 00:00:00   324000.0       3.0       2.25          998       904
# 4  2014-05-10 00:00:00   549900.0       5.0       2.75         3060      7015
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     3.0           0     0          3        1340              0      2008
# 1     2.0           0     0          3        3540              0      2007
# 2     2.0           0     0          3        6420            850      2010
# 3     2.0           0     0          3         798            200      2007
# 4     1.0           0     0          5        1600           1460      1979
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4140 entries, 0 to 4139
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4140 non-null   str
#  1   price          4140 non-null   float64
#  2   bedrooms       4140 non-null   float64
#  3   bathrooms      4140 non-null   float64
#  4   sqft_living    4140 non-null   int64
#  5   sqft_lot       4140 non-null   int64
#  6   floors         4140 non-null   float64
#  7   waterfront     4140 non-null   int64
#  8   view           4140 non-null   int64
#  9   condition      4140 non-null   int64
#  10  sqft_above     4140 non-null   int64
#  11  sqft_basement  4140 non-null   int64
#  12  yr_built       4140 non-null   int64
#  13  yr_renovated   4140 non-null   int64
#  14  street         4140 non-null   str
#  15  city           4140 non-null   str
#  16  statezip       4140 non-null   str
#  17  country        4140 non-null   str
# ...

# %%
data.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.140000e+03  4140.000000  4140.000000   4140.000000  4.140000e+03
# mean   5.530629e+05     3.400483     2.163043   2143.638889  1.469764e+04
# std    5.836865e+05     0.903939     0.784733    957.481621  3.587684e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.200000e+05     3.000000     1.750000   1470.000000  5.000000e+03
# 50%    4.600000e+05     3.000000     2.250000   1980.000000  7.676000e+03
# 75%    6.591250e+05     4.000000     2.500000   2620.000000  1.100000e+04
# max    2.659000e+07     8.000000     6.750000  10040.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4140.000000  4140.000000  4140.000000  4140.000000  4140.000000
# mean      1.514130     0.007488     0.246618     3.452415  1831.351449
# std       0.534941     0.086219     0.790619     0.678533   861.382947
# ...

# %%
data = data[data['price'] > 0]
data.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.091000e+03  4091.000000  4091.000000   4091.000000  4.091000e+03
# mean   5.596872e+05     3.393547     2.156624   2135.931313  1.467661e+04
# std    5.840060e+05     0.899115     0.776501    949.318839  3.596527e+04
# min    7.800000e+03     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.250938e+05     3.000000     1.750000   1460.000000  5.000000e+03
# 50%    4.646000e+05     3.000000     2.250000   1980.000000  7.665000e+03
# 75%    6.600000e+05     4.000000     2.500000   2610.000000  1.095250e+04
# max    2.659000e+07     8.000000     6.750000  10040.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4091.000000  4091.000000  4091.000000  4091.000000  4091.000000
# mean      1.514300     0.006844     0.240039     3.449768  1825.789538
# std       0.535172     0.082457     0.776533     0.676252   852.802465
# ...

# %%
data = data.drop(columns=['country', 'street'])
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4091 entries, 0 to 4139
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4091 non-null   str
#  1   price          4091 non-null   float64
#  2   bedrooms       4091 non-null   float64
#  3   bathrooms      4091 non-null   float64
#  4   sqft_living    4091 non-null   int64
#  5   sqft_lot       4091 non-null   int64
#  6   floors         4091 non-null   float64
#  7   waterfront     4091 non-null   int64
#  8   view           4091 non-null   int64
#  9   condition      4091 non-null   int64
#  10  sqft_above     4091 non-null   int64
#  11  sqft_basement  4091 non-null   int64
#  12  yr_built       4091 non-null   int64
#  13  yr_renovated   4091 non-null   int64
#  14  city           4091 non-null   str
#  15  statezip       4091 non-null   str
# dtypes: float64(4), int64(9), str(3)
# memory usage: 543.3 KB

# %%
# turing date column into just the year
data['sale_year'] = pd.to_datetime(data['date']).dt.year
data.drop(columns=['date'])
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-09 00:00:00   376000.0       3.0       2.00         1340      1384
# 1  2014-05-09 00:00:00   800000.0       4.0       3.25         3540    159430
# 2  2014-05-09 00:00:00  2238888.0       5.0       6.50         7270    130017
# 3  2014-05-09 00:00:00   324000.0       3.0       2.25          998       904
# 4  2014-05-10 00:00:00   549900.0       5.0       2.75         3060      7015
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     3.0           0     0          3        1340              0      2008
# 1     2.0           0     0          3        3540              0      2007
# 2     2.0           0     0          3        6420            850      2010
# 3     2.0           0     0          3         798            200      2007
# 4     1.0           0     0          5        1600           1460      1979
#
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
print((data['bedrooms'] == 0).sum())
print((data['bathrooms'] == 0).sum())
# Out:
# 2
# 2

# %%
data[data['bedrooms'] == 0]
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 1905  2014-06-12 00:00:00  1095000.0       0.0        0.0         3064
# 2749  2014-06-24 00:00:00  1295648.0       0.0        0.0         4810
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 1905      4764     3.5           0     2          3        3064
# 2749     28008     2.0           0     0          3        4810
#
#       sqft_basement  yr_built  yr_renovated     city  statezip  sale_year
# 1905              0      1990          2009  Seattle  WA 98102       2014
# 2749              0      1990          2009  Redmond  WA 98053       2014

# %%
data[data['bathrooms'] == 0]
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 1905  2014-06-12 00:00:00  1095000.0       0.0        0.0         3064
# 2749  2014-06-24 00:00:00  1295648.0       0.0        0.0         4810
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 1905      4764     3.5           0     2          3        3064
# 2749     28008     2.0           0     0          3        4810
#
#       sqft_basement  yr_built  yr_renovated     city  statezip  sale_year
# 1905              0      1990          2009  Seattle  WA 98102       2014
# 2749              0      1990          2009  Redmond  WA 98053       2014
